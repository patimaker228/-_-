-- %% [markdown]
-- # [РемесленныеНавыки]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [РемесленныеНавыки]    Script Date: 09.10.2024 16:35:31 ******/
CREATE DATABASE [РемесленныеНавыки]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'РемесленныеНавыки', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.MSSQLSERVER01\MSSQL\DATA\РемесленныеНавыки.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'РемесленныеНавыки_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.MSSQLSERVER01\MSSQL\DATA\РемесленныеНавыки_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT, LEDGER = OFF
GO
ALTER DATABASE [РемесленныеНавыки] SET COMPATIBILITY_LEVEL = 160
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [РемесленныеНавыки].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [РемесленныеНавыки] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [РемесленныеНавыки] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [РемесленныеНавыки] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [РемесленныеНавыки] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [РемесленныеНавыки] SET ARITHABORT OFF 
GO
ALTER DATABASE [РемесленныеНавыки] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [РемесленныеНавыки] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [РемесленныеНавыки] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [РемесленныеНавыки] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [РемесленныеНавыки] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [РемесленныеНавыки] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [РемесленныеНавыки] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [РемесленныеНавыки] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [РемесленныеНавыки] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [РемесленныеНавыки] SET  DISABLE_BROKER 
GO
ALTER DATABASE [РемесленныеНавыки] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [РемесленныеНавыки] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [РемесленныеНавыки] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [РемесленныеНавыки] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [РемесленныеНавыки] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [РемесленныеНавыки] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [РемесленныеНавыки] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [РемесленныеНавыки] SET RECOVERY FULL 
GO
ALTER DATABASE [РемесленныеНавыки] SET  MULTI_USER 
GO
ALTER DATABASE [РемесленныеНавыки] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [РемесленныеНавыки] SET DB_CHAINING OFF 
GO
ALTER DATABASE [РемесленныеНавыки] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [РемесленныеНавыки] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [РемесленныеНавыки] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [РемесленныеНавыки] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
EXEC sys.sp_db_vardecimal_storage_format N'РемесленныеНавыки', N'ON'
GO
ALTER DATABASE [РемесленныеНавыки] SET QUERY_STORE = ON
GO
ALTER DATABASE [РемесленныеНавыки] SET QUERY_STORE (OPERATION_MODE = READ_WRITE, CLEANUP_POLICY = (STALE_QUERY_THRESHOLD_DAYS = 30), DATA_FLUSH_INTERVAL_SECONDS = 900, INTERVAL_LENGTH_MINUTES = 60, MAX_STORAGE_SIZE_MB = 1000, QUERY_CAPTURE_MODE = AUTO, SIZE_BASED_CLEANUP_MODE = AUTO, MAX_PLANS_PER_QUERY = 200, WAIT_STATS_CAPTURE_MODE = ON)
GO

-- %% [markdown]
-- # [dbo].[Навыки]

-- %%
USE [РемесленныеНавыки]
GO

-- %%
/****** Object:  Table [dbo].[Навыки]    Script Date: 09.10.2024 16:35:31 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Навыки](
	[ИД_навыка] [int] NOT NULL,
	[Название_навыка] [nvarchar](50) NULL,
PRIMARY KEY CLUSTERED 
(
	[ИД_навыка] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Навыки_пользователей]

-- %%
/****** Object:  Table [dbo].[Навыки_пользователей]    Script Date: 09.10.2024 16:35:31 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Навыки_пользователей](
	[ИД_пользователя] [int] NOT NULL,
	[ИД_навыка] [int] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[ИД_пользователя] ASC,
	[ИД_навыка] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Пользователи_]

-- %%
/****** Object:  Table [dbo].[Пользователи_]    Script Date: 09.10.2024 16:35:31 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Пользователи_](
	[ИД_пользователя] [int] NOT NULL,
	[Имя_пользователя] [nvarchar](50) NULL,
	[Почта] [nvarchar](50) NULL,
	[Пароль] [nvarchar](50) NULL,
PRIMARY KEY CLUSTERED 
(
	[ИД_пользователя] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Прогресс_пользователя]

-- %%
/****** Object:  Table [dbo].[Прогресс_пользователя]    Script Date: 09.10.2024 16:35:31 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Прогресс_пользователя](
	[ИД_пользователя] [int] NOT NULL,
	[ИД_материала] [int] NOT NULL,
	[Завершено] [bit] NULL,
PRIMARY KEY CLUSTERED 
(
	[ИД_пользователя] ASC,
	[ИД_материала] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Уроки]

-- %%
/****** Object:  Table [dbo].[Уроки]    Script Date: 09.10.2024 16:35:31 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Уроки](
	[ИД_урока] [int] NOT NULL,
	[Название_урока] [nvarchar](50) NULL,
	[ИД_навыка] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[ИД_урока] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Учебные_материалы]

-- %%
/****** Object:  Table [dbo].[Учебные_материалы]    Script Date: 09.10.2024 16:35:31 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Учебные_материалы](
	[ИД_материала] [int] NOT NULL,
	[Название_материала] [nvarchar](50) NULL,
	[ИД_урока] [int] NULL,
	[Ссылка_на_видео] [nvarchar](100) NULL,
PRIMARY KEY CLUSTERED 
(
	[ИД_материала] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [FK__Навыки_по__ИД_на__4BAC3F29]

-- %%
ALTER TABLE [dbo].[Навыки_пользователей]  WITH CHECK ADD FOREIGN KEY([ИД_навыка])
REFERENCES [dbo].[Навыки] ([ИД_навыка])
GO

-- %% [markdown]
-- # [FK__Навыки_по__ИД_по__4AB81AF0]

-- %%
ALTER TABLE [dbo].[Навыки_пользователей]  WITH CHECK ADD FOREIGN KEY([ИД_пользователя])
REFERENCES [dbo].[Пользователи_] ([ИД_пользователя])
GO

-- %% [markdown]
-- # [FK__Прогресс___ИД_ма__4F7CD00D]

-- %%
ALTER TABLE [dbo].[Прогресс_пользователя]  WITH CHECK ADD FOREIGN KEY([ИД_материала])
REFERENCES [dbo].[Учебные_материалы] ([ИД_материала])
GO

-- %% [markdown]
-- # [FK__Прогресс___ИД_по__4E88ABD4]

-- %%
ALTER TABLE [dbo].[Прогресс_пользователя]  WITH CHECK ADD FOREIGN KEY([ИД_пользователя])
REFERENCES [dbo].[Пользователи_] ([ИД_пользователя])
GO

-- %% [markdown]
-- # [FK__Уроки__ИД_навыка__44FF419A]

-- %%
ALTER TABLE [dbo].[Уроки]  WITH CHECK ADD FOREIGN KEY([ИД_навыка])
REFERENCES [dbo].[Навыки] ([ИД_навыка])
GO

-- %% [markdown]
-- # [FK__Учебные_м__ИД_ур__47DBAE45]

-- %%
ALTER TABLE [dbo].[Учебные_материалы]  WITH CHECK ADD FOREIGN KEY([ИД_урока])
REFERENCES [dbo].[Уроки] ([ИД_урока])
GO

-- %% [markdown]
-- # [РемесленныеНавыки]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [РемесленныеНавыки] SET  READ_WRITE 
GO
